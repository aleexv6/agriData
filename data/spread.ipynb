# %%
import pymongo
import database as db
import pandas as pd
import os

# %%
#for file in format : 2 first letters = ticker, 3rd letter = month expiration and 2 digits year expiration
product = {
    'ML': 'EBM',
    'XR': 'ECO',
    'XB': 'EMA'
}
months = {
    'F': 'JAN',
	'G': 'FEB',
	'H': 'MAR',
	'J': 'APR',
	'K': 'MAY',
	'M': 'JUN',
	'N': 'JUL',
	'Q': 'AUG',
	'U': 'SEP',
	'V': 'OCT',
	'X': 'NOV',
	'Z': 'DEC'
}
directories = ['EBM', 'EMA', 'ECO']
files = [f"{dir}/{f}" for dir in directories for f in os.listdir(f"C:/Users/alexl/Documents/GitHub/agriData/data/data/Futures/{dir}")]
df_list = []
for file in files:
    tmp = pd.read_csv(f'C:/Users/alexl/Documents/GitHub/agriData/data/data/Futures/{file}', skiprows=1).iloc[:-1]
    tmp['Ticker'] = file.split('/')[0]
    tmp['Expiration'] = months.get(file.split('/')[1][2], file.split('/')[1][2]) + file.split('/')[1][3:5]
    df_list.append(tmp)
df = pd.concat(df_list).reset_index(drop=True)
# Out:
# ['EBM/MLF02.csv', 'EBM/MLF03.csv', 'EBM/MLF04.csv', 'EBM/MLF05.csv', 'EBM/MLF06.csv', 'EBM/MLF07.csv', 'EBM/MLF08.csv', 'EBM/MLF09.csv', 'EBM/MLF10.csv', 'EBM/MLF11.csv', 'EBM/MLF12.csv', 'EBM/MLF13.csv', 'EBM/MLF14.csv', 'EBM/MLF15.csv', 'EBM/MLH02.csv', 'EBM/MLH03.csv', 'EBM/MLH04.csv', 'EBM/MLH05.csv', 'EBM/MLH06.csv', 'EBM/MLH07.csv', 'EBM/MLH08.csv', 'EBM/MLH09.csv', 'EBM/MLH10.csv', 'EBM/MLH11.csv', 'EBM/MLH12.csv', 'EBM/MLH13.csv', 'EBM/MLH14.csv', 'EBM/MLH15.csv', 'EBM/MLH16.csv', 'EBM/MLH17.csv', 'EBM/MLH18.csv', 'EBM/MLH19.csv', 'EBM/MLH20.csv', 'EBM/MLH21.csv', 'EBM/MLH22.csv', 'EBM/MLH23.csv', 'EBM/MLH24.csv', 'EBM/MLH25.csv', 'EBM/MLH26.csv', 'EBM/MLH27.csv', 'EBM/MLK02.csv', 'EBM/MLK03.csv', 'EBM/MLK04.csv', 'EBM/MLK05.csv', 'EBM/MLK06.csv', 'EBM/MLK07.csv', 'EBM/MLK08.csv', 'EBM/MLK09.csv', 'EBM/MLK10.csv', 'EBM/MLK11.csv', 'EBM/MLK12.csv', 'EBM/MLK13.csv', 'EBM/MLK14.csv', 'EBM/MLK15.csv', 'EBM/MLK16.csv', 'EBM/MLK17.csv', 'EBM/MLK18.csv', 'EBM/MLK19.csv', 'EBM/MLK20.csv', 'EBM/MLK21.csv', 'EBM/MLK22.csv', 'EBM/MLK23.csv', 'EBM/MLK24.csv', 'EBM/MLK25.csv', 'EBM/MLK26.csv', 'EBM/MLK27.csv', 'EBM/MLN02.csv', 'EBM/MLN03.csv', 'EBM/MLN04.csv', 'EBM
csv', 'EMA/XBM17.csv', 'EMA/XBM18.csv', 'EMA/XBM19.csv', 'EMA/XBM20.csv', 'EMA/XBM21.csv', 'EMA/XBM22.csv', 'EMA/XBM23.csv', 'EMA/XBM24.csv', 'EMA/XBM25.csv', 'EMA/XBM26.csv', 'EMA/XBQ03.csv', 'EMA/XBQ04.csv', 'EMA/XBQ06.csv', 'EMA/XBQ07.csv', 'EMA/XBQ08.csv', 'EMA/XBQ09.csv', 'EMA/XBQ10.csv', 'EMA/XBQ11.csv', 'EMA/XBQ12.csv', 'EMA/XBQ13.csv', 'EMA/XBQ14.csv', 'EMA/XBQ15.csv', 'EMA/XBQ16.csv', 'EMA/XBQ17.csv', 'EMA/XBQ18.csv', 'EMA/XBQ19.csv', 'EMA/XBQ20.csv', 'EMA/XBQ21.csv', 'EMA/XBQ22.csv', 'EMA/XBQ23.csv', 'EMA/XBQ24.csv', 'EMA/XBQ25.csv', 'EMA/XBQ26.csv', 'EMA/XBX03.csv', 'EMA/XBX04.csv', 'EMA/XBX05.csv', 'EMA/XBX06.csv', 'EMA/XBX07.csv', 'EMA/XBX08.csv', 'EMA/XBX09.csv', 'EMA/XBX10.csv', 'EMA/XBX11.csv', 'EMA/XBX12.csv', 'EMA/XBX13.csv', 'EMA/XBX14.csv', 'EMA/XBX15.csv', 'EMA/XBX16.csv', 'EMA/XBX17.csv', 'EMA/XBX18.csv', 'EMA/XBX19.csv', 'EMA/XBX20.csv', 'EMA/XBX21.csv', 'EMA/XBX22.csv', 'EMA/XBX23.csv', 'EMA/XBX24.csv', 'EMA/XBX25.csv', 'EMA/XBX26.csv', 'ECO/XRG02.csv', 'ECO/XRG03.csv', 'ECO ...

# %%
df = df.rename(columns={'Date Time': 'Date'})
df = df[['Date', 'Ticker', 'Expiration', 'Open', 'High', 'Low', 'Close', 'Volume', 'Open Interest']].sort_values(by='Date').reset_index(drop=True)
df
# Out:
#               Date Ticker Expiration    Open    High     Low   Close  Volume  \
# 0       2001-09-17    EBM      JAN02  122.00  122.00  121.50  121.75     NaN
# 1       2001-09-17    EBM      MAY02  123.25  123.75  123.25  123.75     NaN
# 2       2001-09-17    EBM      JUL02  126.00  126.00  126.00  126.00     NaN
# 3       2001-09-17    EBM      SEP02  120.00  120.00  120.00  120.00     NaN
# 4       2001-09-17    ECO      NOV02  238.00  238.00  236.00  236.00     NaN
# ...            ...    ...        ...     ...     ...     ...     ...     ...
# 150298  2024-07-11    ECO      AUG24  476.00  479.75  475.00  476.50  4448.0
# 150299  2024-07-11    ECO      NOV24  483.50  486.50  481.50  482.00  7527.0
# 150300  2024-07-11    ECO      AUG25  467.50  471.25  467.25  470.75     7.0
# 150301  2024-07-11    EMA      MAR25  211.00  216.00  210.75  215.00   638.0
# 150302  2024-07-11    EMA      NOV24  207.25  211.75  207.25  211.25   878.0
#
#         Open Interest
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 150298            NaN
# 150299            NaN
# 150300            NaN
# 150301            NaN
# 150302            NaN
#
# [150303 rows x 9 columns]
